# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get("https://www.ambitionbox.com/list-of-companies?page=1",headers=headers).text
soup=BeautifulSoup(webpage,'lxml')

# %%
com=soup.find_all("div",class_="companyCardWrapper")

# %%
len(com)
# Out:
# 20

# %%
name=[]
rating=[]
techLoc=[]
ctype=[]
sector=[]
old=[]
employees=[]
location=[]
reviews=[]
salaries=[]
interviews=[]

for i in com:
    name.append(i.find("h2").text.strip())
    rating.append(i.find("span", class_="companyCardWrapper__companyRatingValue").text.strip())
    techLoc.append(i.find_all("span", class_="companyCardWrapper__interLinking")[0].text.strip())
    value=j.split("|")
    ctype.append(value[0])
    employees.append(value[1])
    sector.append(value[2])
    old.append(value[3])
    if len(value)==5:
        location.append(value[4])         
    else:
        location.append("NaN")
    reviews.append(i.find_all("span",class_="companyCardWrapper__ActionCount")[0].text.strip())
    salaries.append(i.find_all("span",class_="companyCardWrapper__ActionCount")[1].text.strip())
    interviews.append(i.find_all("span",class_="companyCardWrapper__ActionCount")[2].text.strip())


d={"name":name,"rating":rating,"reviews":reviews,"salaries":salaries,"interviews":interviews,"ctype":ctype,"employees":employees,"old":old,"sector":sector,"location":location}

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#                        name rating reviews salaries interviews  ctype  \
# 0                       TCS    3.7   72.8k   856.4k         6k  NBFC
# 1                 Accenture    4.0   46.1k   584.5k       4.2k  NBFC
# 2                 Cognizant    3.8   41.4k   560.6k       3.5k  NBFC
# 3                     Wipro    3.7   38.8k   427.9k       3.6k  NBFC
# 4                 HDFC Bank    3.8   33.7k   140.3k       1.5k  NBFC
# 5                ICICI Bank    4.0   33.4k   143.5k       1.8k  NBFC
# 6                   Infosys    3.8   31.6k   462.6k       4.7k  NBFC
# 7                 Capgemini    3.8   29.5k   373.7k       2.4k  NBFC
# 8                   HCLTech    3.6   28.3k   292.2k       2.5k  NBFC
# 9             Tech Mahindra    3.6   27.5k   251.9k       2.4k  NBFC
# 10                  Genpact    3.9     26k   190.4k       1.9k  NBFC
# 11                Axis Bank    3.8   21.9k    97.9k       1.1k  NBFC
# 12          Teleperformance    3.7   21.8k    83.3k       1.2k  NBFC
# ...
